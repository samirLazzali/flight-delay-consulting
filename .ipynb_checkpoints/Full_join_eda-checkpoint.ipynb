# %%
import pandas as pd, seaborn as sns, numpy as np, matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)  
import warnings
#warnings.filterwarnings(action='once')
warnings.filterwarnings('ignore')
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
raw_full_join = pd.read_csv("full_join.csv")

# %%
full_join = raw_full_join.copy()
full_join = full_join.rename(columns={
'COMPAGNIE AERIENNE':'COMPAGNIE_CODE',
})

# %%
def _encode_dates(X):
    X_encoded = X.copy()
    X_encoded.loc[:, 'DATE'] = pd.to_datetime(X_encoded['DATE'], format="%d/%m/%Y", errors="coerce")
    X_encoded.loc[:, 'year'] = X_encoded['DATE'].dt.year
    X_encoded.loc[:, 'month'] = X_encoded['DATE'].dt.month
    X_encoded.loc[:, 'day'] = X_encoded['DATE'].dt.day
    X_encoded.loc[:, 'weekday'] = X_encoded['DATE'].dt.weekday
    X_encoded.loc[:, 'week'] = X_encoded['DATE'].dt.week
    return X_encoded.drop(columns=["DATE"])

#date_encoder = FunctionTransformer(_encode_dates)
#date_encoder.fit_transform(vols).head()
full_join = _encode_dates(full_join)
full_join.head()
# Out:
#    IDENTIFIANT   VOL  CODE_AVION AEROPORT_DEPART AEROPORT_ARRIVEE  \
# 0       651373  2317  28fa5df4d7             TIA              DSS
# 1      3901402  2514  068d0a9b31             TIA              DXB
# 2      3622626   607  433ee3f85e             TIA              BOH
# 3      4373289    17  17a3a5b0b4             TIA              VIE
# 4      1750929   897  b8bb13dc3a             TIA              SXF
#
#    HEURE_DEPART_PROGRAMME  HEURE_DEPART  TEMPS_RETARD_DEPART  \
# 0                    1410        1411.0                  1.0
# 1                    1606        1610.0                  4.0
# 2                    2235        2233.0                 -2.0
# 3                     155         150.0                 -5.0
# 4                     730         725.0                 -5.0
#
#    TEMPS_DEPLACEMENT_DECOLLAGE  HEURE_DECOLLAGE  TEMPS_PROGRAMME  TEMPS_PASSE  \
# 0                         20.0           1431.0            229.0        227.0
# 1                         18.0           1628.0            164.0        162.0
# 2                         15.0           2248.0            268.0        261.0
# 3                          9.0            159.0            365.0        367.0
# 4                         15.0            740.0             90.0         84.0
#
#    TEMPS_VOL  DISTANCE  HEURE_ATTERRISSAGE  TEMPS_DEPLACEMENT_ATTERRISSAGE  \
# 0      197.0      1749              2048.0                            10.0
# 1      128.0      1055              2036.0                            16.0
# 2      241.0      2176               549.0                             5.0
# 3      351.0      2762               450.0                             7.0
# 4       63.0       414               843.0                             6.0
#
#    HEURE_ARRIVEE_PROGRAMMEE  HEURE_ARRIVEE  TEMPS_RETARD_ARRIVEE  \
# 0                      2059         2058.0                  -1.0
# 1                      2050         2052.0                   2.0
# 2                       603          554.0                  -9.0
# 3                       500          457.0                  -3.0
# 4                       900          849.0                 -11.0
#
#    DETOURNEMENT  ANNULATION RAISON_ANNULATION  RETARD_SYSTEM  RETARD_SECURITE  \
# 0             0           0               NaN            NaN              NaN
# 1             0           0               NaN            NaN              NaN
# 2             0           0               NaN            NaN              NaN
# 3             0           0               NaN            NaN              NaN
# 4             0           0               NaN            NaN              NaN
#
#    RETARD_COMPAGNIE  RETARD_AVION  RETARD_METEO  NIVEAU_SECURITE  \
# 0               NaN           NaN           NaN               10
# 1               NaN           NaN           NaN               10
# 2               NaN           NaN           NaN               10
# 3               NaN           NaN           NaN               10
# 4               NaN           NaN           NaN               10
#
#   COMPAGNIE_CODE                     COMPAGNIE  \
# 0          NVPPA    Ne Va Pas Partout Airlines
# 1            COA    Corporate Overlord Airways
# 2            NaN            Neverland Airlines
# 3             AP                   Air Penguin
# 4          BTATA  Better Take A Train Airlines
#
#                                    DEPART_NOM DEPART_LIEU DEPART_PAYS  \
# 0  Tirana International Airport Mother Teresa      Tirana          AL
# 1  Tirana International Airport Mother Teresa      Tirana          AL
# 2  Tirana International Airport Mother Teresa      Tirana          AL
# 3  Tirana International Airport Mother Teresa      Tirana          AL
# 4  Tirana International Airport Mother Teresa      Tirana          AL
#
#    DEPART_LONGITUDE  DEPART_LATITUDE  DEPART_HAUTEUR  DEPART_PRIX_RETARD_10  \
# 0           19.7206          41.4147           126.0                   4582
# 1           19.7206          41.4147           126.0                   4582
# 2           19.7206          41.4147           126.0                   4582
# 3           19.7206          41.4147           126.0                   4582
# 4           19.7206          41.4147           126.0                   4582
#
#    DEPART_PRIX_RETARD_APRES                                 ARRIVEE_NOM  \
# 0                       586  Tirana International Airport Mother Teresa
# 1                       586  Tirana International Airport Mother Teresa
# 2                       586  Tirana International Airport Mother Teresa
# 3                       586  Tirana International Airport Mother Teresa
# 4                       586  Tirana International Airport Mother Teresa
#
#   ARRIVEE_LIEU ARRIVEE_PAYS  ARRIVEE_LONGITUDE  ARRIVEE_LATITUDE  \
# 0       Tirana           AL            19.7206           41.4147
# 1       Tirana           AL            19.7206           41.4147
# 2       Tirana           AL            19.7206           41.4147
# 3       Tirana           AL            19.7206           41.4147
# 4       Tirana           AL            19.7206           41.4147
#
#    ARRIVEE_HAUTEUR  ARRIVEE_PRIX_RETARD_10  ARRIVEE_PRIX_RETARD_APRES  year  \
# 0            126.0                    4582                        586  2016
# 1            126.0                    4582                        586  2018
# 2            126.0                    4582                        586  2016
# 3            126.0                    4582                        586  2018
# 4            126.0                    4582                        586  2017
#
#    month  day  weekday  week
# 0      4   10        6    14
# 1     11   24        5    47
# 2      3   21        0    12
# 3      8   23        3    34
# 4      6    6        1    23

# %%
print(full_join.shape)
full_join.head(2) #(3000000, 47)
# Out:
# (3000000, 47)
#    IDENTIFIANT   VOL  CODE_AVION AEROPORT_DEPART AEROPORT_ARRIVEE  \
# 0       651373  2317  28fa5df4d7             TIA              DSS
# 1      3901402  2514  068d0a9b31             TIA              DXB
#
#    HEURE_DEPART_PROGRAMME  HEURE_DEPART  TEMPS_RETARD_DEPART  \
# 0                    1410        1411.0                  1.0
# 1                    1606        1610.0                  4.0
#
#    TEMPS_DEPLACEMENT_DECOLLAGE  HEURE_DECOLLAGE  TEMPS_PROGRAMME  TEMPS_PASSE  \
# 0                         20.0           1431.0            229.0        227.0
# 1                         18.0           1628.0            164.0        162.0
#
#    TEMPS_VOL  DISTANCE  HEURE_ATTERRISSAGE  TEMPS_DEPLACEMENT_ATTERRISSAGE  \
# 0      197.0      1749              2048.0                            10.0
# 1      128.0      1055              2036.0                            16.0
#
#    HEURE_ARRIVEE_PROGRAMMEE  HEURE_ARRIVEE  TEMPS_RETARD_ARRIVEE  \
# 0                      2059         2058.0                  -1.0
# 1                      2050         2052.0                   2.0
#
#    DETOURNEMENT  ANNULATION RAISON_ANNULATION  RETARD_SYSTEM  RETARD_SECURITE  \
# 0             0           0               NaN            NaN              NaN
# 1             0           0               NaN            NaN              NaN
#
#    RETARD_COMPAGNIE  RETARD_AVION  RETARD_METEO        DATE  NIVEAU_SECURITE  \
# 0               NaN           NaN           NaN   10/4/2016               10
# 1               NaN           NaN           NaN  24/11/2018               10
#
#   COMPAGNIE_CODE                   COMPAGNIE  \
# 0          NVPPA  Ne Va Pas Partout Airlines
# 1            COA  Corporate Overlord Airways
#
#                                    DEPART_NOM DEPART_LIEU DEPART_PAYS  \
# 0  Tirana International Airport Mother Teresa      Tirana          AL
# 1  Tirana International Airport Mother Teresa      Tirana          AL
#
#    DEPART_LONGITUDE  DEPART_LATITUDE  DEPART_HAUTEUR  DEPART_PRIX_RETARD_10  \
# 0           19.7206          41.4147           126.0                   4582
# 1           19.7206          41.4147           126.0                   4582
#
#    DEPART_PRIX_RETARD_APRES                                 ARRIVEE_NOM  \
# 0                       586  Tirana International Airport Mother Teresa
# 1                       586  Tirana International Airport Mother Teresa
#
#   ARRIVEE_LIEU ARRIVEE_PAYS  ARRIVEE_LONGITUDE  ARRIVEE_LATITUDE  \
# 0       Tirana           AL            19.7206           41.4147
# 1       Tirana           AL            19.7206           41.4147
#
#    ARRIVEE_HAUTEUR  ARRIVEE_PRIX_RETARD_10  ARRIVEE_PRIX_RETARD_APRES
# 0            126.0                    4582                        586
# 1            126.0                    4582                        586

# %%
# Prix retard à l'arrivé par PAYS (DEPART_PRIX_RETARD_10 ~ ARRIVEE_PRIX_RETARD_10)
print("Moyenne du prix des retards à l'arrivé : ",int(full_join['ARRIVEE_PRIX_RETARD_10'].mean()),"$")
sns.distplot(full_join['ARRIVEE_PRIX_RETARD_10'])
print(full_join[['ARRIVEE_PAYS','ARRIVEE_PRIX_RETARD_10']].groupby('ARRIVEE_PAYS').mean().sort_values(by='ARRIVEE_PRIX_RETARD_10').head(5))
print(full_join[['ARRIVEE_PAYS','ARRIVEE_PRIX_RETARD_10']].groupby('ARRIVEE_PAYS').mean().sort_values(by='ARRIVEE_PRIX_RETARD_10',ascending=False).head(5))
# full_join['AEROPORT_DEPART'].value_counts()
# full_join['AEROPORT_ARRIVEE'].value_counts()
# Out:
# Moyenne du prix des retards à l'arrivé :  5113 $
#               ARRIVEE_PRIX_RETARD_10
# ARRIVEE_PAYS
# LY                             105.0
# MU                             160.0
# LR                             307.0
# SG                             553.0
# NE                             610.0
#               ARRIVEE_PRIX_RETARD_10
# ARRIVEE_PAYS
# MY                            9773.0
# UG                            9744.0
# MA                            9420.0
# SC                            9364.0
# HU                            9319.0

# %%
# Prix retard à l'arrivé par Aeroport (DEPART_PRIX_RETARD_10 ~ ARRIVEE_PRIX_RETARD_10)
print("Moyenne du prix des retards à l'arrivé : ",int(full_join['ARRIVEE_PRIX_RETARD_10'].mean()),"$")
print(full_join[['AEROPORT_DEPART','DEPART_PRIX_RETARD_10']].groupby('AEROPORT_DEPART').mean().sort_values(by='DEPART_PRIX_RETARD_10').head(5))
print(full_join[['AEROPORT_DEPART','DEPART_PRIX_RETARD_10']].groupby('AEROPORT_DEPART').mean().sort_values(by='DEPART_PRIX_RETARD_10',ascending=False).head(5))
# Out:
# Moyenne du prix des retards à l'arrivé :  5113 $
#                  DEPART_PRIX_RETARD_10
# AEROPORT_DEPART
# TIP                                105
# MRU                                160
# GOA                                166
# VAR                                174
# BGW                                214
#                  DEPART_PRIX_RETARD_10
# AEROPORT_DEPART
# TSF                               9877
# KUL                               9773
# KBP                               9757
# HGH                               9753
# EBB                               9744

# %%
# Prix retard à l'arrivé par Aeroport (DEPART_PRIX_RETARD_10 ~ ARRIVEE_PRIX_RETARD_10)
print("Moyenne du prix des retards à l'arrivé : ",int(full_join['ARRIVEE_PRIX_RETARD_10'].mean()),"$")
print(full_join[['AEROPORT_DEPART','DEPART_PRIX_RETARD_10']].groupby('AEROPORT_DEPART').mean().sort_values(by='DEPART_PRIX_RETARD_10').head(5))
print(full_join[['AEROPORT_DEPART','DEPART_PRIX_RETARD_10']].groupby('AEROPORT_DEPART').mean().sort_values(by='DEPART_PRIX_RETARD_10',ascending=False).head(5))
# Out:
# Moyenne du prix des retards à l'arrivé :  5113 $
#                  DEPART_PRIX_RETARD_10
# AEROPORT_DEPART
# TIP                                105
# MRU                                160
# GOA                                166
# VAR                                174
# BGW                                214
#                  DEPART_PRIX_RETARD_10
# AEROPORT_DEPART
# TSF                               9877
# KUL                               9773
# KBP                               9757
# HGH                               9753
# EBB                               9744

# %%
def delay_byTime(min_delay, first_ten, minutes_after_ten):
    if min_delay <= 0 :
        return 0
    elif min_delay <= 10 : 
        return first_ten
    else :
        return first_ten + (min_delay - 10)*minutes_after_ten
    
RETARD_DEPART = full_join[['AEROPORT_DEPART', 'TEMPS_RETARD_DEPART','DEPART_PRIX_RETARD_10', 'DEPART_PRIX_RETARD_APRES']]
RETARD_DEPART['PRIX_RETARD_DEPART'] = RETARD_DEPART.apply(lambda row : delay_byTime(row['TEMPS_RETARD_DEPART'], row['DEPART_PRIX_RETARD_10'], row['DEPART_PRIX_RETARD_APRES']), axis=1)
RETARD_DEPART.head()
# Out:
#   AEROPORT_DEPART  TEMPS_RETARD_DEPART  DEPART_PRIX_RETARD_10  \
# 0             TIA                  1.0                   4582
# 1             TIA                  4.0                   4582
# 2             TIA                 -2.0                   4582
# 3             TIA                 -5.0                   4582
# 4             TIA                 -5.0                   4582
#
#    DEPART_PRIX_RETARD_APRES  PRIX_RETARD_DEPART
# 0                       586              4582.0
# 1                       586              4582.0
# 2                       586                 0.0
# 3                       586                 0.0
# 4                       586                 0.0

# %%
# evolution dans le temps - ajouter les années
sns.distplot(RETARD_DEPART.groupby('AEROPORT_DEPART').mean()['PRIX_RETARD_DEPART'])
RETARD_DEPART.groupby('AEROPORT_DEPART').mean().sort_values(by='PRIX_RETARD_DEPART',ascending=False).head(5)
# Out:
#                  TEMPS_RETARD_DEPART  DEPART_PRIX_RETARD_10  \
# AEROPORT_DEPART
# SIP                        25.953488                   4242
# ZRH                        28.900000                   9451
# OTP                        12.070093                   7891
# LYS                        17.871116                   5934
# CJJ                        11.416514                   7282
#
#                  DEPART_PRIX_RETARD_APRES  PRIX_RETARD_DEPART
# AEROPORT_DEPART
# SIP                                   662        19511.162791
# ZRH                                   479        17978.813333
# OTP                                   977        15768.574766
# LYS                                   664        15317.341772
# CJJ                                   984        15121.744954

# %%
plt.figure(figsize=(15,7))
#RETARD_DEPART.groupby('AEROPORT_DEPART').mean().sort_values(by='PRIX_RETARD_DEPART',ascending=False).head(5).plot.bar()
RETARD_DEPART_top_15 = RETARD_DEPART.groupby('AEROPORT_DEPART').mean()['PRIX_RETARD_DEPART'].sort_values(ascending=False).head(15)
RETARD_DEPART_top_15.plot.bar()
plt.show()
RETARD_DEPART_bottom_15 = RETARD_DEPART.groupby('AEROPORT_DEPART').mean()['PRIX_RETARD_DEPART'].sort_values().head(15)
plt.figure(figsize=(15,7))
RETARD_DEPART_bottom_15.plot.bar()

# plt.xticks(rotation=50)
# plt.xlabel("Country of Origin")
# plt.ylabel("Number of Wines")
# plt.show()

# %%
# Ceux qui paient le plus :
raw_text = RETARD_DEPART.groupby('AEROPORT_DEPART').mean()['PRIX_RETARD_DEPART'].sort_values(ascending=False).head(30).reset_index().apply(lambda row : (str(row.AEROPORT_DEPART)+' ') * int(row.PRIX_RETARD_DEPART), axis=1)
text = " ".join(code for code in raw_text)
# Create and generate a word cloud image:
wordcloud = WordCloud(background_color="white",collocations=False).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
raw_text = RETARD_DEPART_top_15.reset_index().apply(lambda row : (str(row.AEROPORT_DEPART)+' ') * int(row.PRIX_RETARD_DEPART), axis=1)
text = " ".join(code for code in raw_text)
text
# Out:
# 'SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP SIP ...

# %%
full_join.head(1)
# Out:
#    IDENTIFIANT   VOL  CODE_AVION AEROPORT_DEPART AEROPORT_ARRIVEE  \
# 0       651373  2317  28fa5df4d7             TIA              DSS
#
#    HEURE_DEPART_PROGRAMME  HEURE_DEPART  TEMPS_RETARD_DEPART  \
# 0                    1410        1411.0                  1.0
#
#    TEMPS_DEPLACEMENT_DECOLLAGE  HEURE_DECOLLAGE  TEMPS_PROGRAMME  TEMPS_PASSE  \
# 0                         20.0           1431.0            229.0        227.0
#
#    TEMPS_VOL  DISTANCE  HEURE_ATTERRISSAGE  TEMPS_DEPLACEMENT_ATTERRISSAGE  \
# 0      197.0      1749              2048.0                            10.0
#
#    HEURE_ARRIVEE_PROGRAMMEE  HEURE_ARRIVEE  TEMPS_RETARD_ARRIVEE  \
# 0                      2059         2058.0                  -1.0
#
#    DETOURNEMENT  ANNULATION RAISON_ANNULATION  RETARD_SYSTEM  RETARD_SECURITE  \
# 0             0           0               NaN            NaN              NaN
#
#    RETARD_COMPAGNIE  RETARD_AVION  RETARD_METEO       DATE  NIVEAU_SECURITE  \
# 0               NaN           NaN           NaN  10/4/2016               10
#
#   COMPAGNIE_CODE                   COMPAGNIE  \
# 0          NVPPA  Ne Va Pas Partout Airlines
#
#                                    DEPART_NOM DEPART_LIEU DEPART_PAYS  \
# 0  Tirana International Airport Mother Teresa      Tirana          AL
#
#    DEPART_LONGITUDE  DEPART_LATITUDE  DEPART_HAUTEUR  DEPART_PRIX_RETARD_10  \
# 0           19.7206          41.4147           126.0                   4582
#
#    DEPART_PRIX_RETARD_APRES                                 ARRIVEE_NOM  \
# 0                       586  Tirana International Airport Mother Teresa
#
#   ARRIVEE_LIEU ARRIVEE_PAYS  ARRIVEE_LONGITUDE  ARRIVEE_LATITUDE  \
# 0       Tirana           AL            19.7206           41.4147
#
#    ARRIVEE_HAUTEUR  ARRIVEE_PRIX_RETARD_10  ARRIVEE_PRIX_RETARD_APRES
# 0            126.0                    4582                        586
